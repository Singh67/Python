# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('pokemon.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 11 columns):
# Attack        801 non-null int64
# Defense       801 non-null int64
# HP            801 non-null int64
# Name          801 non-null object
# Sp_attack     801 non-null int64
# Sp_defense    801 non-null int64
# Speed         801 non-null int64
# Type1         801 non-null object
# Type2         417 non-null object
# Generation    801 non-null int64
# Legendary     801 non-null int64
# dtypes: int64(8), object(3)
# memory usage: 68.9+ KB

# %%
data.corr()
# Out:
#               Attack   Defense        HP  Sp_attack  Sp_defense     Speed  \
# Attack      1.000000  0.468915  0.410616   0.368154    0.265836  0.352703
# Defense     0.468915  1.000000  0.242378   0.241882    0.526348  0.007934
# HP          0.410616  0.242378  1.000000   0.365973    0.366971  0.160760
# Sp_attack   0.368154  0.241882  0.365973   1.000000    0.511496  0.438981
# Sp_defense  0.265836  0.526348  0.366971   0.511496    1.000000  0.225977
# Speed       0.352703  0.007934  0.160760   0.438981    0.225977  1.000000
# Generation  0.101375  0.057603  0.074065   0.070146    0.048711 -0.019914
# Legendary   0.303295  0.265587  0.308405   0.406281    0.343241  0.311639
#
#             Generation  Legendary
# Attack        0.101375   0.303295
# Defense       0.057603   0.265587
# HP            0.074065   0.308405
# Sp_attack     0.070146   0.406281
# Sp_defense    0.048711   0.343241
# Speed        -0.019914   0.311639
# Generation    1.000000   0.139029
# ...

# %%
f,ax=plt.subplots(figsize=(18,18))
sns.heatmap(data.corr(),annot=True,linewidths=.5,fmt='.1f',ax=ax)
plt.show()

# %%
data.head(4)
# Out:
#    Attack  Defense  HP        Name  Sp_attack  Sp_defense  Speed  Type1  \
# 0      49       49  45   Bulbasaur         65          65     45  grass
# 1      62       63  60     Ivysaur         80          80     60  grass
# 2     100      123  80    Venusaur        122         120     80  grass
# 3      52       43  39  Charmander         60          50     65   fire
#
#     Type2  Generation  Legendary
# 0  poison           1          0
# 1  poison           1          0
# 2  poison           1          0
# 3     NaN           1          0

# %%
data.columns
# Out:
# Index(['Attack', 'Defense', 'HP', 'Name', 'Sp_attack', 'Sp_defense', 'Speed',
#        'Type1', 'Type2', 'Generation', 'Legendary'],
#       dtype='object')

# %%
data.Speed.plot(kind='line',color='g',label='Speed',linewidth=1,alpha=0.5,grid=True,linestyle=':')
data.Sp_defense.plot(color='r',label='Defence',linewidth=1,alpha=0.5,grid=True,linestyle='-.')
plt.legend(loc='upper right')
plt.show()

# %%
data.plot(kind='scatter',x='Attack',y='Defense',alpha=0.5,color='red')
plt.show()

# %%
data.Speed.plot(kind='hist',bins=50,figsize=(10,10))
plt.show()

# %%
data[data['Defense']>200]
# Out:
#      Attack  Defense  HP     Name  Sp_attack  Sp_defense  Speed  Type1  \
# 207     125      230  75  Steelix         55          95     30  steel
# 212      10      230  20  Shuckle         10         230      5    bug
# 305     140      230  70   Aggron         60          80     50  steel
#
#       Type2  Generation  Legendary
# 207  ground           2          0
# 212    rock           2          0
# 305    rock           3          0

# %%
data[np.logical_and(data['Defense']>200 ,data['Attack']>100)]
# Out:
#      Attack  Defense  HP     Name  Sp_attack  Sp_defense  Speed  Type1  \
# 207     125      230  75  Steelix         55          95     30  steel
# 305     140      230  70   Aggron         60          80     50  steel
#
#       Type2  Generation  Legendary
# 207  ground           2          0
# 305    rock           3          0

# %%
data[(data['Defense'] >200) & (data['Attack']>100)]
# Out:
#      Attack  Defense  HP     Name  Sp_attack  Sp_defense  Speed  Type1  \
# 207     125      230  75  Steelix         55          95     30  steel
# 305     140      230  70   Aggron         60          80     50  steel
#
#       Type2  Generation  Legendary
# 207  ground           2          0
# 305    rock           3          0

# %%
lis=[1,2,3,4,5]
for index,value in enumerate(lis):
    print(value)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for index, value in data[['Attack']][0:1].iterrows():
    print(value)
# Out:
# Attack    49
# Name: 0, dtype: int64

# %%
def tupe_ex():
    t=(1,2,3)
    return t

a,b,c=tupe_ex()
print(a,b,c)
# Out:
# 1 2 3

# %%
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %%
def square():
    def add():
        x=2
        y=3
        z=x + y
        return z
    
    return add() **2
print(square())
# Out:
# 25

# %%
def f(a,b=1,c=2):
    y=a + b+ c
    return y
print(f(5))
# Out:
# 8

# %%
print(f(1,2,3))
# Out:
# 6

# %%
def f(*args):
    for i in args:
        print(i)

# %%
f(1)
# Out:
# 1

# %%
f(1,2,3,4)
# Out:
# 1
# 2
# 3
# 4

# %%
def f(**kwargs):
    for key ,value in kwargs.items():
        print(key,"",value)

# %%
f(country='spain',capital='madrid',population=123456)
# Out:
# country  spain
# capital  madrid
# population  123456

# %%
square=lambda x: x**2
print(square(2))
# Out:
# 4

# %%
tot=lambda x,y,z:x + y+ z
print(tot(1,2,3))
# Out:
# 6

# %%
number_list=[1,2,3]
y=map(lambda x: x**2 ,number_list)

# %%
print(list(y))
# Out:
# [1, 4, 9]

# %%
name="ronaldo"
it=iter(name)
print(next(it))
print(*it)
# Out:
# r
# o n a l d o

# %%
list1=[1,2,3,4,5]
list2=[8,9,2,3,]
z=zip(list1,list2)
z1=list(z)
print(z1)
# Out:
# [(1, 8), (2, 9), (3, 2), (4, 3)]

# %%
un_zip=zip(*z1)
un_l1,un_l2=list(un_zip)
print(un_l1)
print(un_l2)
# Out:
# (1, 2, 3, 4)
# (8, 9, 2, 3)

# %%
num1=[1,2,3]
num2=[i+1 for i in num1]
print(num2)
# Out:
# [2, 3, 4]

# %%
num1=[5,10,15]
num2=[i**2 if i==10 else i-5 if i<7 else i+5 for i in num1]
print(num2)
# Out:
# [0, 100, 20]

# %%
threshold=sum(data.Speed)/len(data.Speed)
data['speed_level']=["high" if i>threshold else "low" for i in data.Speed]

# %%
data.loc[:10,["speed_level","Speed"]]
# Out:
#    speed_level  Speed
# 0          low     45
# 1          low     60
# 2         high     80
# 3          low     65
# 4         high     80
# 5         high    100
# 6          low     43
# 7          low     58
# 8         high     78
# 9          low     45
# 10         low     30

# %%
data=pd.read_csv('pokemon.csv')

# %%
data.head()
# Out:
#    Attack  Defense  HP        Name  Sp_attack  Sp_defense  Speed  Type1  \
# 0      49       49  45   Bulbasaur         65          65     45  grass
# 1      62       63  60     Ivysaur         80          80     60  grass
# 2     100      123  80    Venusaur        122         120     80  grass
# 3      52       43  39  Charmander         60          50     65   fire
# 4      64       58  58  Charmeleon         80          65     80   fire
#
#     Type2  Generation  Legendary
# 0  poison           1          0
# 1  poison           1          0
# 2  poison           1          0
# 3     NaN           1          0
# 4     NaN           1          0

# %%
data.tail()
# Out:
#      Attack  Defense   HP        Name  Sp_attack  Sp_defense  Speed    Type1  \
# 796     101      103   97  Celesteela        107         101     61    steel
# 797     181      131   59     Kartana         59          31    109    grass
# 798     101       53  223    Guzzlord         97          53     43     dark
# 799     107      101   97    Necrozma        127          89     79  psychic
# 800      95      115   80    Magearna        130         115     65    steel
#
#       Type2  Generation  Legendary
# 796  flying           7          1
# 797   steel           7          1
# 798  dragon           7          1
# 799     NaN           7          1
# 800   fairy           7          1

# %%
data.columns
# Out:
# Index(['Attack', 'Defense', 'HP', 'Name', 'Sp_attack', 'Sp_defense', 'Speed',
#        'Type1', 'Type2', 'Generation', 'Legendary'],
#       dtype='object')

# %%
data.shape
# Out:
# (801, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 11 columns):
# Attack        801 non-null int64
# Defense       801 non-null int64
# HP            801 non-null int64
# Name          801 non-null object
# Sp_attack     801 non-null int64
# Sp_defense    801 non-null int64
# Speed         801 non-null int64
# Type1         801 non-null object
# Type2         417 non-null object
# Generation    801 non-null int64
# Legendary     801 non-null int64
# dtypes: int64(8), object(3)
# memory usage: 68.9+ KB

# %%
print(data['Type1'].value_counts(dropna=False))
# Out:
# water       114
# normal      105
# grass        78
# bug          72
# psychic      53
# fire         52
# rock         45
# electric     39
# ground       32
# poison       32
# dark         29
# fighting     28
# ghost        27
# dragon       27
# steel        24
# ice          23
# fairy        18
# flying        3
# Name: Type1, dtype: int64

# %%
data.describe()
# Out:
#            Attack     Defense          HP   Sp_attack  Sp_defense       Speed  \
# count  801.000000  801.000000  801.000000  801.000000  801.000000  801.000000
# mean    77.857678   73.008739   68.958801   71.305868   70.911361   66.334582
# std     32.158820   30.769159   26.576015   32.353826   27.942501   28.907662
# min      5.000000    5.000000    1.000000   10.000000   20.000000    5.000000
# 25%     55.000000   50.000000   50.000000   45.000000   50.000000   45.000000
# 50%     75.000000   70.000000   65.000000   65.000000   66.000000   65.000000
# 75%    100.000000   90.000000   80.000000   91.000000   90.000000   85.000000
# max    185.000000  230.000000  255.000000  194.000000  230.000000  180.000000
#
#        Generation   Legendary
# count  801.000000  801.000000
# mean     3.690387    0.087391
# std      1.930420    0.282583
# min      1.000000    0.000000
# 25%      2.000000    0.000000
# 50%      4.000000    0.000000
# 75%      5.000000    0.000000
# ...

# %%
data.boxplot(column='Attack',by='Legendary')
plt.show()
# Out:
# C:\Users\Satish\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
data_new=data.head(5)

# %%
data_new
# Out:
#    Attack  Defense  HP        Name  Sp_attack  Sp_defense  Speed  Type1  \
# 0      49       49  45   Bulbasaur         65          65     45  grass
# 1      62       63  60     Ivysaur         80          80     60  grass
# 2     100      123  80    Venusaur        122         120     80  grass
# 3      52       43  39  Charmander         60          50     65   fire
# 4      64       58  58  Charmeleon         80          65     80   fire
#
#     Type2  Generation  Legendary
# 0  poison           1          0
# 1  poison           1          0
# 2  poison           1          0
# 3     NaN           1          0
# 4     NaN           1          0

# %%
melted=pd.melt(frame=data_new,id_vars='Name',value_vars=['Attack','Defense'])

# %%
melted
# Out:
#          Name variable  value
# 0   Bulbasaur   Attack     49
# 1     Ivysaur   Attack     62
# 2    Venusaur   Attack    100
# 3  Charmander   Attack     52
# 4  Charmeleon   Attack     64
# 5   Bulbasaur  Defense     49
# 6     Ivysaur  Defense     63
# 7    Venusaur  Defense    123
# 8  Charmander  Defense     43
# 9  Charmeleon  Defense     58

# %%
melted.pivot(index='Name',columns='variable',values='value')
# Out:
# variable    Attack  Defense
# Name
# Bulbasaur       49       49
# Charmander      52       43
# Charmeleon      64       58
# Ivysaur         62       63
# Venusaur       100      123

# %%
data1=data.head()
data2=data.tail()
con_data=pd.concat([data1,data2],axis=0,ignore_index=True)
con_data
# Out:
#    Attack  Defense   HP        Name  Sp_attack  Sp_defense  Speed    Type1  \
# 0      49       49   45   Bulbasaur         65          65     45    grass
# 1      62       63   60     Ivysaur         80          80     60    grass
# 2     100      123   80    Venusaur        122         120     80    grass
# 3      52       43   39  Charmander         60          50     65     fire
# 4      64       58   58  Charmeleon         80          65     80     fire
# 5     101      103   97  Celesteela        107         101     61    steel
# 6     181      131   59     Kartana         59          31    109    grass
# 7     101       53  223    Guzzlord         97          53     43     dark
# 8     107      101   97    Necrozma        127          89     79  psychic
# 9      95      115   80    Magearna        130         115     65    steel
#
#     Type2  Generation  Legendary
# 0  poison           1          0
# 1  poison           1          0
# 2  poison           1          0
# ...

# %%
data1=data['Attack'].head()
data2=data['Defense'].head()
con_data_col=pd.concat([data1,data2],axis=1)

# %%
con_data_col
# Out:
#    Attack  Defense
# 0      49       49
# 1      62       63
# 2     100      123
# 3      52       43
# 4      64       58

# %%
data.dtypes
# Out:
# Attack         int64
# Defense        int64
# HP             int64
# Name          object
# Sp_attack      int64
# Sp_defense     int64
# Speed          int64
# Type1         object
# Type2         object
# Generation     int64
# Legendary      int64
# dtype: object

# %%
data['Type1']=data['Type1'].astype('category')

# %%
data.dtypes
# Out:
# Attack           int64
# Defense          int64
# HP               int64
# Name            object
# Sp_attack        int64
# Sp_defense       int64
# Speed            int64
# Type1         category
# Type2           object
# Generation       int64
# Legendary        int64
# dtype: object

# %%
data['Type2'].value_counts(dropna=False)
# Out:
# NaN         384
# flying       95
# ground       34
# poison       34
# psychic      29
# fairy        29
# fighting     25
# steel        22
# dark         21
# grass        20
# water        17
# dragon       17
# ice          15
# rock         14
# ghost        14
# fire         13
# electric      9
# bug           5
# normal        4
# Name: Type2, dtype: int64

# %%
data1=data.loc[:,["Attack","Defense","Speed"]]
data1.plot()

# %%
data1.plot(subplots=True)
plt.show()

# %%
data1.plot(kind='scatter',x='Attack',y='Defense')
plt.show()

# %%
data1.plot(kind='hist',y='Defense',bins=50,range=(0,250),normed=True)
# Out:
# C:\Users\Satish\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
fig,axes=plt.subplots(nrows=2,ncols=1)
data1.plot(kind='hist',y='Defense',bins=50,normed=True,ax=axes[0])
data1.plot(kind='hist',y='Defense',bins=50,normed=True,cumulative=True,ax=axes[1])
plt.show()
# Out:
# C:\Users\Satish\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
data.describe()
# Out:
#            Attack     Defense          HP   Sp_attack  Sp_defense       Speed  \
# count  801.000000  801.000000  801.000000  801.000000  801.000000  801.000000
# mean    77.857678   73.008739   68.958801   71.305868   70.911361   66.334582
# std     32.158820   30.769159   26.576015   32.353826   27.942501   28.907662
# min      5.000000    5.000000    1.000000   10.000000   20.000000    5.000000
# 25%     55.000000   50.000000   50.000000   45.000000   50.000000   45.000000
# 50%     75.000000   70.000000   65.000000   65.000000   66.000000   65.000000
# 75%    100.000000   90.000000   80.000000   91.000000   90.000000   85.000000
# max    185.000000  230.000000  255.000000  194.000000  230.000000  180.000000
#
#        Generation   Legendary
# count  801.000000  801.000000
# mean     3.690387    0.087391
# std      1.930420    0.282583
# min      1.000000    0.000000
# 25%      2.000000    0.000000
# 50%      4.000000    0.000000
# 75%      5.000000    0.000000
# ...

# %%
import warnings
warnings.filterwarnings("ignore")
data2=data.head()

# %%
date_list=["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
datetime_object=pd.to_datetime(date_list)
data2['date']=datetime_object
data2=data2.set_index('date')

# %%
data2
# Out:
#             Attack  Defense  HP        Name  Sp_attack  Sp_defense  Speed  \
# date
# 1992-01-10      49       49  45   Bulbasaur         65          65     45
# 1992-02-10      62       63  60     Ivysaur         80          80     60
# 1992-03-10     100      123  80    Venusaur        122         120     80
# 1993-03-15      52       43  39  Charmander         60          50     65
# 1993-03-16      64       58  58  Charmeleon         80          65     80
#
#             Type1   Type2  Generation  Legendary
# date
# 1992-01-10  grass  poison           1          0
# 1992-02-10  grass  poison           1          0
# 1992-03-10  grass  poison           1          0
# 1993-03-15   fire     NaN           1          0
# 1993-03-16   fire     NaN           1          0

# %%
print(data2.loc["1993-03-16"])
# Out:
# Attack                64
# Defense               58
# HP                    58
# Name          Charmeleon
# Sp_attack             80
# Sp_defense            65
# Speed                 80
# Type1               fire
# Type2                NaN
# Generation             1
# Legendary              0
# Name: 1993-03-16 00:00:00, dtype: object

# %%
print(data2.loc["1992-03-10":"1993-03-16"])
# Out:
#             Attack  Defense  HP        Name  Sp_attack  Sp_defense  Speed  \
# date
# 1992-03-10     100      123  80    Venusaur        122         120     80
# 1993-03-15      52       43  39  Charmander         60          50     65
# 1993-03-16      64       58  58  Charmeleon         80          65     80
#
#             Type1   Type2  Generation  Legendary
# date
# 1992-03-10  grass  poison           1          0
# 1993-03-15   fire     NaN           1          0
# 1993-03-16   fire     NaN           1          0

# %%
data2.resample("A").mean()
# Out:
#                Attack    Defense         HP  Sp_attack  Sp_defense      Speed  \
# date
# 1992-12-31  70.333333  78.333333  61.666667       89.0   88.333333  61.666667
# 1993-12-31  58.000000  50.500000  48.500000       70.0   57.500000  72.500000
#
#             Generation  Legendary
# date
# 1992-12-31         1.0        0.0
# 1993-12-31         1.0        0.0

# %%
data2.resample("M").mean()
# Out:
#             Attack  Defense    HP  Sp_attack  Sp_defense  Speed  Generation  \
# date
# 1992-01-31    49.0     49.0  45.0       65.0        65.0   45.0         1.0
# 1992-02-29    62.0     63.0  60.0       80.0        80.0   60.0         1.0
# 1992-03-31   100.0    123.0  80.0      122.0       120.0   80.0         1.0
# 1992-04-30     NaN      NaN   NaN        NaN         NaN    NaN         NaN
# 1992-05-31     NaN      NaN   NaN        NaN         NaN    NaN         NaN
# 1992-06-30     NaN      NaN   NaN        NaN         NaN    NaN         NaN
# 1992-07-31     NaN      NaN   NaN        NaN         NaN    NaN         NaN
# 1992-08-31     NaN      NaN   NaN        NaN         NaN    NaN         NaN
# 1992-09-30     NaN      NaN   NaN        NaN         NaN    NaN         NaN
# 1992-10-31     NaN      NaN   NaN        NaN         NaN    NaN         NaN
# 1992-11-30     NaN      NaN   NaN        NaN         NaN    NaN         NaN
# ...

# %%
data2.resample("M").first().interpolate("linear")
# Out:
#             Attack     Defense         HP        Name   Sp_attack  Sp_defense  \
# date
# 1992-01-31    49.0   49.000000  45.000000   Bulbasaur   65.000000   65.000000
# 1992-02-29    62.0   63.000000  60.000000     Ivysaur   80.000000   80.000000
# 1992-03-31   100.0  123.000000  80.000000    Venusaur  122.000000  120.000000
# 1992-04-30    96.0  116.333333  76.583333         NaN  116.833333  114.166667
# 1992-05-31    92.0  109.666667  73.166667         NaN  111.666667  108.333333
# 1992-06-30    88.0  103.000000  69.750000         NaN  106.500000  102.500000
# 1992-07-31    84.0   96.333333  66.333333         NaN  101.333333   96.666667
# 1992-08-31    80.0   89.666667  62.916667         NaN   96.166667   90.833333
# 1992-09-30    76.0   83.000000  59.500000         NaN   91.000000   85.000000
# 1992-10-31    72.0   76.333333  56.083333         NaN   85.833333   79.166667
# 1992-11-30    68.0   69.666667  52.666667         NaN   80.666667   73.333333
# ...

# %%
data2.resample("M").mean().interpolate("linear")
# Out:
#             Attack     Defense      HP   Sp_attack  Sp_defense   Speed  \
# date
# 1992-01-31    49.0   49.000000  45.000   65.000000   65.000000  45.000
# 1992-02-29    62.0   63.000000  60.000   80.000000   80.000000  60.000
# 1992-03-31   100.0  123.000000  80.000  122.000000  120.000000  80.000
# 1992-04-30    96.5  116.958333  77.375  117.666667  114.791667  79.375
# 1992-05-31    93.0  110.916667  74.750  113.333333  109.583333  78.750
# 1992-06-30    89.5  104.875000  72.125  109.000000  104.375000  78.125
# 1992-07-31    86.0   98.833333  69.500  104.666667   99.166667  77.500
# 1992-08-31    82.5   92.791667  66.875  100.333333   93.958333  76.875
# 1992-09-30    79.0   86.750000  64.250   96.000000   88.750000  76.250
# 1992-10-31    75.5   80.708333  61.625   91.666667   83.541667  75.625
# 1992-11-30    72.0   74.666667  59.000   87.333333   78.333333  75.000
# 1992-12-31    68.5   68.625000  56.375   83.000000   73.125000  74.375
# ...

# %%
data["HP"][0]
# Out:
# 45

# %%
data2[["HP","Attack"]]
# Out:
#             HP  Attack
# date
# 1992-01-10  45      49
# 1992-02-10  60      62
# 1992-03-10  80     100
# 1993-03-15  39      52
# 1993-03-16  58      64

# %%
data.loc[1:10,"Attack":"HP"]
# Out:
#     Attack  Defense  HP
# 1       62       63  60
# 2      100      123  80
# 3       52       43  39
# 4       64       58  58
# 5      104       78  78
# 6       48       65  44
# 7       63       80  59
# 8      103      120  79
# 9       30       35  45
# 10      20       55  50

# %%
data.loc[10:1:-1,"Attack":"HP"]
# Out:
#     Attack  Defense  HP
# 10      20       55  50
# 9       30       35  45
# 8      103      120  79
# 7       63       80  59
# 6       48       65  44
# 5      104       78  78
# 4       64       58  58
# 3       52       43  39
# 2      100      123  80
# 1       62       63  60

# %%
data.loc[1:10,"Speed":]
# Out:
#     Speed  Type1   Type2  Generation  Legendary
# 1      60  grass  poison           1          0
# 2      80  grass  poison           1          0
# 3      65   fire     NaN           1          0
# 4      80   fire     NaN           1          0
# 5     100   fire  flying           1          0
# 6      43  water     NaN           1          0
# 7      58  water     NaN           1          0
# 8      78  water     NaN           1          0
# 9      45    bug     NaN           1          0
# 10     30    bug     NaN           1          0

# %%
boolean=data['HP']>200

# %%
data[boolean]
# Out:
#      Attack  Defense   HP      Name  Sp_attack  Sp_defense  Speed   Type1  \
# 112       5        5  250   Chansey         35         105     50  normal
# 241      10       10  255   Blissey         75         135     55  normal
# 717     100      121  216   Zygarde         91          95     85  dragon
# 798     101       53  223  Guzzlord         97          53     43    dark
#
#       Type2  Generation  Legendary
# 112     NaN           1          0
# 241     NaN           2          0
# 717  ground           6          1
# 798  dragon           7          1

# %%
first_filter=data["HP"]>150
second_filter=data["Speed"] >50
data[first_filter & second_filter]
# Out:
#      Attack  Defense   HP       Name  Sp_attack  Sp_defense  Speed   Type1  \
# 241      10       10  255    Blissey         75         135     55  normal
# 320      90       45  170    Wailord         90          45     60   water
# 593      75       80  165  Alomomola         40          45     65   water
# 717     100      121  216    Zygarde         91          95     85  dragon
#
#       Type2  Generation  Legendary
# 241     NaN           2          0
# 320     NaN           3          0
# 593     NaN           5          0
# 717  ground           6          1

# %%
data[(data["HP"]>150) & (data["Speed"] >50)]
# Out:
#      Attack  Defense   HP       Name  Sp_attack  Sp_defense  Speed   Type1  \
# 241      10       10  255    Blissey         75         135     55  normal
# 320      90       45  170    Wailord         90          45     60   water
# 593      75       80  165  Alomomola         40          45     65   water
# 717     100      121  216    Zygarde         91          95     85  dragon
#
#       Type2  Generation  Legendary
# 241     NaN           2          0
# 320     NaN           3          0
# 593     NaN           5          0
# 717  ground           6          1

# %%
data['HP'][data['Speed']<15]
# Out:
# 212     20
# 327     45
# 437     50
# 445    135
# 596     44
# 770     55
# Name: HP, dtype: int64

# %%
def div(n):
    return n/2
data['HP'].apply(div)
# Out:
# 0       22.5
# 1       30.0
# 2       40.0
# 3       19.5
# 4       29.0
# 5       39.0
# 6       22.0
# 7       29.5
# 8       39.5
# 9       22.5
# 10      25.0
# 11      30.0
# 12      20.0
# 13      22.5
# 14      32.5
# 15      20.0
# 16      31.5
# 17      41.5
# 18      15.0
# 19      37.5
# 20      20.0
# 21      32.5
# 22      17.5
# 23      30.0
# 24      17.5
# 25      30.0
# 26      25.0
# 27      37.5
# 28      27.5
# 29      35.0
#        ...
# 771     47.5
# 772     47.5
# 773     30.0
# 774     32.5
# 775     30.0
# 776     32.5
# 777     27.5
# 778     34.0
# 779     39.0
# 780     35.0
# 781     22.5
# 782     27.5
# 783     37.5
# 784     35.0
# 785     35.0
# 786     35.0
# 787     35.0
# 788     21.5
# 789     21.5
# 790     68.5
# 791     68.5
# 792     54.5
# 793     53.5
# 794     35.5
# 795     41.5
# 796     48.5
# 797     29.5
# 798    111.5
# 799     48.5
# 800     40.0
# Name: HP, Length: 801, dtype: float64

# %%
data['HP'].apply(lambda n: n/2)
# Out:
# 0       22.5
# 1       30.0
# 2       40.0
# 3       19.5
# 4       29.0
# 5       39.0
# 6       22.0
# 7       29.5
# 8       39.5
# 9       22.5
# 10      25.0
# 11      30.0
# 12      20.0
# 13      22.5
# 14      32.5
# 15      20.0
# 16      31.5
# 17      41.5
# 18      15.0
# 19      37.5
# 20      20.0
# 21      32.5
# 22      17.5
# 23      30.0
# 24      17.5
# 25      30.0
# 26      25.0
# 27      37.5
# 28      27.5
# 29      35.0
#        ...
# 771     47.5
# 772     47.5
# 773     30.0
# 774     32.5
# 775     30.0
# 776     32.5
# 777     27.5
# 778     34.0
# 779     39.0
# 780     35.0
# 781     22.5
# 782     27.5
# 783     37.5
# 784     35.0
# 785     35.0
# 786     35.0
# 787     35.0
# 788     21.5
# 789     21.5
# 790     68.5
# 791     68.5
# 792     54.5
# 793     53.5
# 794     35.5
# 795     41.5
# 796     48.5
# 797     29.5
# 798    111.5
# 799     48.5
# 800     40.0
# Name: HP, Length: 801, dtype: float64

# %%
data['total_power']=data['Attack'] + data['Defense']

# %%
data.head()
# Out:
#    Attack  Defense  HP        Name  Sp_attack  Sp_defense  Speed  Type1  \
# 0      49       49  45   Bulbasaur         65          65     45  grass
# 1      62       63  60     Ivysaur         80          80     60  grass
# 2     100      123  80    Venusaur        122         120     80  grass
# 3      52       43  39  Charmander         60          50     65   fire
# 4      64       58  58  Charmeleon         80          65     80   fire
#
#     Type2  Generation  Legendary  total_power
# 0  poison           1          0           98
# 1  poison           1          0          125
# 2  poison           1          0          223
# 3     NaN           1          0           95
# 4     NaN           1          0          122

# %%
data.index.name='index_name'

# %%
data.head()
# Out:
#             Attack  Defense  HP        Name  Sp_attack  Sp_defense  Speed  \
# index_name
# 0               49       49  45   Bulbasaur         65          65     45
# 1               62       63  60     Ivysaur         80          80     60
# 2              100      123  80    Venusaur        122         120     80
# 3               52       43  39  Charmander         60          50     65
# 4               64       58  58  Charmeleon         80          65     80
#
#             Type1   Type2  Generation  Legendary  total_power
# index_name
# 0           grass  poison           1          0           98
# 1           grass  poison           1          0          125
# 2           grass  poison           1          0          223
# 3            fire     NaN           1          0           95
# 4            fire     NaN           1          0          122

# %%
data1=data.set_index(['Type1','Type2'])

# %%
data1
# Out:
#                    Attack  Defense   HP        Name  Sp_attack  Sp_defense  \
# Type1    Type2
# grass    poison        49       49   45   Bulbasaur         65          65
#          poison        62       63   60     Ivysaur         80          80
#          poison       100      123   80    Venusaur        122         120
# fire     NaN           52       43   39  Charmander         60          50
#          NaN           64       58   58  Charmeleon         80          65
#          flying       104       78   78   Charizard        159         115
# water    NaN           48       65   44    Squirtle         50          64
#          NaN           63       80   59   Wartortle         65          80
#          NaN          103      120   79   Blastoise        135         115
# bug      NaN           30       35   45    Caterpie         20          20
#          NaN           20       55   50     Metapod         25          25
# ...
